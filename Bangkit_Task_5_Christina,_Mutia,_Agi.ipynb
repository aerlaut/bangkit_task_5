# %% [markdown]
# <a href="https://colab.research.google.com/github/aerlaut/bangkit_task_5/blob/master/Bangkit_Task_5_Christina%2C_Mutia%2C_Agi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Predicting AirBNB Price
#
# This collab notebook is written for Bangkit Task 5.
#
# In this book, we utilise Tensorflow to make an anime recommendation engine based on the public dataset available at : https://www.kaggle.com/stevezhenghp/airbnb-price-prediction
#
# Some of the features are cut out of the sample data to reduce data size. The resulting file is uploaded to Google Drive ([airbnb_price.csv](https://drive.google.com/open?id=1S5hFEprXxLUEfsnQ0sczo_smmc3tA49D)) and referred in the code.

# %%
# Importing data pydrive as per example: https://colab.research.google.com/notebooks/io.ipynb#scrollTo=k9q0pp33dckN
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticating and getting file instance
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Creating file
csv_url = "https://drive.google.com/open?id=1S5hFEprXxLUEfsnQ0sczo_smmc3tA49D"
file_id = csv_url.split('=')[-1]

csv_file = drive.CreateFile({'id':file_id}) 
csv_file.GetContentFile('airbnb_price.csv')

# %%
# Importing relevant libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('airbnb_price.csv')
df = pd.DataFrame.from_records(data)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df.head()
# Out:
#    Unnamed: 0        id  log_price  ... instant_bookable bedrooms beds
# 0           0   6901257   5.010635  ...                f      1.0  1.0
# 1           1   6304928   5.129899  ...                t      3.0  3.0
# 2           2   7919400   4.976734  ...                t      1.0  3.0
# 3           3  13418779   6.620073  ...                f      2.0  2.0
# 4           4   3808709   4.744932  ...                t      0.0  1.0
#
# [5 rows x 15 columns]

# %% [markdown]
# Preparing data :
# - Renaming columns
# - Scoring `amenities` by the number of amenities offered
# - Replacing and categorizing `property_type`
# - Filling missing values in `bathrooms`, `bedrooms` and `beds`
#
# And converting one-hot categorical values

# %%
# rename id to airbnb_id, and Unnamed: 0 to row_id
df = df.rename(columns={'Unnamed: 0' : 'row_id', 'id' : 'airbnb_id'})

df['amenities'] = df['amenities'].apply(lambda x: x.replace('{', '').replace('}', '').replace("'", '').replace('"', '').replace(' ', '_'))
df['amenities'] = df['amenities'].str.split(',').str.len()

# Replace categories that are types of houses or apartments
df.property_type.replace({
    'Townhouse': 'House',
    'Serviced apartment': 'Apartment',
    'Loft': 'Apartment',
    'Bungalow': 'House',
    'Cottage': 'House',
    'Villa': 'House',
    'Tiny house': 'House',
    'Earth house': 'House',
    'Chalet': 'House'  
    })

# Replace other properties with 'other'
df.loc[~df.property_type.isin(['House', 'Apartment']), 'property_type'] = 'Other'

#Fill Missing value 
df['bathrooms'].fillna(df['bathrooms'].mean(), inplace=True)
df['beds'].fillna(df['beds'].mean(), inplace=True)
df['bedrooms'].fillna(df['bedrooms'].mean(), inplace=True)

#convert categorical column into dummy 
df['instant_bookable'] = df['instant_bookable'].apply(lambda x: {"t":1, "f":0}.get(x,x))
df['cleaning_fee']= df['cleaning_fee'].replace({True: 1, False: 0})

df = pd.concat([df, pd.get_dummies(df['property_type'], prefix='property_type')], axis=1)
df = pd.concat([df, pd.get_dummies(df['cancellation_policy'], prefix='cancellation_policy')], axis=1)
df = pd.concat([df, pd.get_dummies(df['city'], prefix="city")], axis=1)
df = pd.concat([df, pd.get_dummies(df['room_type'], prefix="room_type")], axis=1)

# %%
df.head()
# Out:
#    row_id  airbnb_id  ...  room_type_Private room room_type_Shared room
# 0       0    6901257  ...                       0                     0
# 1       1    6304928  ...                       0                     0
# 2       2    7919400  ...                       0                     0
# 3       3   13418779  ...                       0                     0
# 4       4    3808709  ...                       0                     0
#
# [5 rows x 32 columns]

# %% [markdown]
# Data prep is done. Now we can prepare the data for the model.
# Data is shuffled and split  into training (70%) and test (30%) set.

# %%
#shuffling data
shuffled_df = df.reindex(np.random.permutation(df.index))

import math
training_split_line = math.floor(shuffled_df['row_id'].count() * 0.7)

#Split training (70%) and testing (30%)
training_df = shuffled_df.iloc[:training_split_line, :]
test_df = shuffled_df.iloc[training_split_line: , :]

print("Number of rows : ")
print("training_df : " + str(training_df['row_id'].count()))
print("testing_df : " + str(test_df['row_id'].count()))
# Out:
# Number of rows :
# training_df : 51877
# testing_df : 22234

# %% [markdown]
# Once the data is split, is it prepped for training in Tensorflow. Features are chosen accordingly,

# %%
# import tensorflow as tf
# %tensorflow_version 1.x
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# Choose features to train

features = ['amenities',
            'accommodates',
            'bathrooms',
            'cleaning_fee',
            'instant_bookable',
            'bedrooms',
            'beds',
            'property_type_Apartment',
            'property_type_House',
            'property_type_Other',
            'cancellation_policy_flexible',
            'cancellation_policy_moderate',
            'cancellation_policy_strict',
            'cancellation_policy_super_strict_30',
            'cancellation_policy_super_strict_60',
            'city_Boston',
            'city_Chicago',
            'city_DC',
            'city_LA',
            'city_NYC',
            'city_SF',
            'room_type_Entire home/apt',
            'room_type_Private room',
            'room_type_Shared room']

# Load the entire data into a matrix
x_train = np.matrix(training_df.loc[:, features]).transpose()

# Load entire label intro matrix
y_train = np.matrix(training_df['log_price'])

# And make a convenient variable to remember the number of input columns 
n = len(features)
# Out:
# TensorFlow 1.x selected.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# Regression is modelled as y = Ax + b. A and b are tensorflow variables that can change

# %%
# Define data placeholders
x = tf.placeholder(tf.float32, shape=(n, None))
y = tf.placeholder(tf.float32, shape=(1, None))

# Define trainable variables
# with tf.variable_scope(reuse=tf.AUTO_REUSE):
A = tf.get_variable("A", shape=(1, n))
b = tf.get_variable("b", shape=())

# %% [markdown]
# Model is trained using gradient descent using the chosen hyperparameters. Loss function is calculated with RMSE.

# %%
# Define model output
y_predicted = tf.matmul(A, x) + b

# Define the loss function
loss = tf.reduce_mean(tf.square(y_predicted - y))
learning_rate = 0.001
training_epochs = 2000
loss_history = np.empty(shape=[1],dtype=float)

# Define optimizer object
training_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

# Create a session and initialize variables
session = tf.Session()
session.run(tf.global_variables_initializer())

# Main optimization loop
for epoch in range(training_epochs):
    _, current_loss, current_A, current_b = session.run([training_step, loss, A, b], feed_dict={
        x: x_train,
        y: y_train
    })
    print("epoch = %g, loss = %g" % (epoch, current_loss))
    loss_history = np.append(loss_history,session.run(loss,feed_dict={x: x_train, y: y_train}))
# Out:
# epoch = 0, loss = 178.576
# epoch = 1, loss = 16.0631
# epoch = 2, loss = 6.15423
# epoch = 3, loss = 5.498
# epoch = 4, loss = 5.40396
# epoch = 5, loss = 5.34523
# epoch = 6, loss = 5.28984
# epoch = 7, loss = 5.23582
# epoch = 8, loss = 5.18303
# epoch = 9, loss = 5.13143
# epoch = 10, loss = 5.08099
# epoch = 11, loss = 5.03167
# epoch = 12, loss = 4.98346
# epoch = 13, loss = 4.93632
# epoch = 14, loss = 4.89022
# epoch = 15, loss = 4.84515
# epoch = 16, loss = 4.80107
# epoch = 17, loss = 4.75797
# epoch = 18, loss = 4.71581
# epoch = 19, loss = 4.67457
# epoch = 20, loss = 4.63424
# epoch = 21, loss = 4.59478
# epoch = 22, loss = 4.55618
# epoch = 23, loss = 4.51841
# epoch = 24, loss = 4.48146
# epoch = 25, loss = 4.4453
# epoch = 26, loss = 4.40992
# epoch = 27, loss = 4.37529
# epoch = 28, loss = 4.3414
# epoch = 29, loss = 4.30823
# epoch = 30, loss = 4.27575
# epoch = 31, loss = 4.24396
# epoch = 32, loss = 4.21284
# epoch = 33, loss = 4.18237
# epoch = 34, loss = 4.15253
# epoch = 35, loss = 4.12331
# epoch = 36, loss = 4.09469
# epoch = 37, loss = 4.06666
# epoch = 38, loss = 4.0392
# epoch = 39, loss = 4.01231
# epoch = 40, loss = 3.98596
# epoch = 41, loss = 3.96014
# epoch = 42, loss = 3.93484
# epoch = 43, loss = 3.91005
# epoch = 44, loss = 3.88575
# epoch = 45, loss = 3.86193
# epoch = 46, loss = 3.83858
# epoch = 47, loss = 3.81569
# epoch = 48, loss = 3.79325
# epoch = 49, loss = 3.77125
# epoch = 50, loss = 3.74967
# epoch = 51, loss = 3.72851
# epoch = 52, loss = 3.70775
# epoch = 53, loss = 3.68739
# epoch = 54, loss = 3.66741
# epoch = 55, loss = 3.64781
# epoch = 56, loss = 3.62857
# epoch = 57, loss = 3.6097
# epoch = 58, loss = 3.59117
# epoch = 59, loss = 3.57298
# epoch = 60, loss = 3.55513
# epoch = 61, loss = 3.5376
# epoch = 62, loss = 3.52039
# epoch = 63, loss = 3.50349
# epoch = 64, loss = 3.48688
# epoch = 65, loss = 3.47058
# epoch = 66, loss = 3.45456
# epoch = 67, loss = 3.43882
# epoch = 68, loss = 3.42335
# epoch = 69, loss = 3.40815
# epoch = 70, loss = 3.39321
# epoch = 71, loss = 3.37853
# epoch = 72, loss = 3.36409
# epoch = 73, loss = 3.34989
# epoch = 74, loss = 3.33593
# epoch = 75, loss = 3.32221
# epoch = 76, loss = 3.3087
# epoch = 77, loss = 3.29542
# epoch = 78, loss = 3.28235
# epoch = 79, loss = 3.26949
# epoch = 80, loss = 3.25684
# epoch = 81, loss = 3.24438
# epoch = 82, loss = 3.23212
# epoch = 83, loss = 3.22005
# epoch = 84, loss = 3.20816
# epoch = 85, loss = 3.19646
# epoch = 86, loss = 3.18493
# epoch = 87, loss = 3.17358
# epoch = 88, loss = 3.1624
# epoch = 89, loss = 3.15138
# epoch = 90, loss = 3.14052
# epoch = 91, loss = 3.12981
# epoch = 92, loss = 3.11927
# epoch = 93, loss = 3.10887
# epoch = 94, loss = 3.09861
# epoch = 95, loss = 3.0885
# epoch = 96, loss = 3.07853
# epoch = 97, loss = 3.0687
# epoch = 98, loss = 3.059
# epoch = 99, loss = 3.04943
# epoch = 100, loss = 3.03999
# epoch = 101, loss = 3.03067
# epoch = 102, loss = 3.02147
# epoch = 103, loss = 3.01239
# epoch = 104, loss = 3.00343
# epoch = 105, loss = 2.99458
# epoch = 106, loss = 2.98584
# epoch = 107, loss = 2.97721
# epoch = 108, loss = 2.96869
# epoch = 109, loss = 2.96027
# epoch = 110, loss = 2.95195
# epoch = 111, loss = 2.94372
# epoch = 112, loss = 2.9356
# epoch = 113, loss = 2.92757
# epoch = 114, loss = 2.91963
# epoch = 115, loss = 2.91178
# epoch = 116, loss = 2.90402
# epoch = 117, loss = 2.89634
# epoch = 118, loss = 2.88875
# epoch = 119, loss = 2.88125
# epoch = 120, loss = 2.87382
# epoch = 121, loss = 2.86647
# epoch = 122, loss = 2.8592
# epoch = 123, loss = 2.852
# epoch = 124, loss = 2.84488
# epoch = 125, loss = 2.83783
# epoch = 126, loss = 2.83085
# epoch = 127, loss = 2.82394
# epoch = 128, loss = 2.8171
# epoch = 129, loss = 2.81032
# epoch = 130, loss = 2.80361
# epoch = 131, loss = 2.79696
# epoch = 132, loss = 2.79038
# epoch = 133, loss = 2.78385
# epoch = 134, loss = 2.77738
# epoch = 135, loss = 2.77098
# epoch = 136, loss = 2.76462
# epoch = 137, loss = 2.75833
# epoch = 138, loss = 2.75209
# epoch = 139, loss = 2.7459
# epoch = 140, loss = 2.73977
# epoch = 141, loss = 2.73368
# epoch = 142, loss = 2.72765
# epoch = 143, loss = 2.72167
# epoch = 144, loss = 2.71573
# epoch = 145, loss = 2.70984
# epoch = 146, loss = 2.704
# epoch = 147, loss = 2.6982
# epoch = 148, loss = 2.69245
# epoch = 149, loss = 2.68674
# epoch = 150, loss = 2.68108
# epoch = 151, loss = 2.67545
# epoch = 152, loss = 2.66987
# epoch = 153, loss = 2.66433
# epoch = 154, loss = 2.65883
# epoch = 155, loss = 2.65336
# epoch = 156, loss = 2.64794
# epoch = 157, loss = 2.64255
# epoch = 158, loss = 2.6372
# epoch = 159, loss = 2.63188
# epoch = 160, loss = 2.6266
# epoch = 161, loss = 2.62135
# epoch = 162, loss = 2.61614
# epoch = 163, loss = 2.61096
# epoch = 164, loss = 2.60582
# epoch = 165, loss = 2.6007
# epoch = 166, loss = 2.59562
# epoch = 167, loss = 2.59057
# epoch = 168, loss = 2.58555
# epoch = 169, loss = 2.58056
# epoch = 170, loss = 2.5756
# epoch = 171, loss = 2.57067
# epoch = 172, loss = 2.56576
# epoch = 173, loss = 2.56089
# epoch = 174, loss = 2.55604
# epoch = 175, loss = 2.55122
# epoch = 176, loss = 2.54642
# epoch = 177, loss = 2.54165
# epoch = 178, loss = 2.53691
# epoch = 179, loss = 2.53219
# epoch = 180, loss = 2.5275
# epoch = 181, loss = 2.52283
# epoch = 182, loss = 2.51818
# epoch = 183, loss = 2.51356
# epoch = 184, loss = 2.50896
# epoch = 185, loss = 2.50439
# epoch = 186, loss = 2.49984
# epoch = 187, loss = 2.49531
# epoch = 188, loss = 2.4908
# epoch = 189, loss = 2.48631
# epoch = 190, loss = 2.48184
# epoch = 191, loss = 2.4774
# epoch = 192, loss = 2.47297
# epoch = 193, loss = 2.46857
# epoch = 194, loss = 2.46418
# epoch = 195, loss = 2.45982
# epoch = 196, loss = 2.45548
# epoch = 197, loss = 2.45115
# epoch = 198, loss = 2.44684
# epoch = 199, loss = 2.44255
# epoch = 200, loss = 2.43828
# epoch = 201, loss = 2.43403
# epoch = 202, loss = 2.4298
# epoch = 203, loss = 2.42558
# epoch = 204, loss = 2.42138
# epoch = 205, loss = 2.4172
# epoch = 206, loss = 2.41303
# epoch = 207, loss = 2.40888
# epoch = 208, loss = 2.40475
# epoch = 209, loss = 2.40064
# epoch = 210, loss = 2.39654
# epoch = 211, loss = 2.39245
# epoch = 212, loss = 2.38838
# epoch = 213, loss = 2.38433
# epoch = 214, loss = 2.38029
# epoch = 215, loss = 2.37627
# epoch = 216, loss = 2.37226
# epoch = 217, loss = 2.36827
# epoch = 218, loss = 2.36429
# epoch = 219, loss = 2.36033
# epoch = 220, loss = 2.35638
# epoch = 221, loss = 2.35245
# epoch = 222, loss = 2.34852
# epoch = 223, loss = 2.34462
# epoch = 224, loss = 2.34072
# epoch = 225, loss = 2.33684
# epoch = 226, loss = 2.33298
# epoch = 227, loss = 2.32912
# epoch = 228, loss = 2.32528
# epoch = 229, loss = 2.32145
# epoch = 230, loss = 2.31764
# epoch = 231, loss = 2.31384
# epoch = 232, loss = 2.31005
# epoch = 233, loss = 2.30627
# epoch = 234, loss = 2.30251
# epoch = 235, loss = 2.29875
# epoch = 236, loss = 2.29501
# epoch = 237, loss = 2.29129
# epoch = 238, loss = 2.28757
# epoch = 239, loss = 2.28386
# epoch = 240, loss = 2.28017
# epoch = 241, loss = 2.27649
# epoch = 242, loss = 2.27282
# epoch = 243, loss = 2.26916
# epoch = 244, loss = 2.26551
# epoch = 245, loss = 2.26188
# epoch = 246, loss = 2.25825
# epoch = 247, loss = 2.25464
# epoch = 248, loss = 2.25104
# epoch = 249, loss = 2.24744
# epoch = 250, loss = 2.24386
# epoch = 251, loss = 2.24029
# epoch = 252, loss = 2.23673
# epoch = 253, loss = 2.23318
# epoch = 254, loss = 2.22964
# epoch = 255, loss = 2.22611
# epoch = 256, loss = 2.22259
# epoch = 257, loss = 2.21909
# epoch = 258, loss = 2.21559
# epoch = 259, loss = 2.2121
# epoch = 260, loss = 2.20862
# epoch = 261, loss = 2.20515
# epoch = 262, loss = 2.20169
# epoch = 263, loss = 2.19824
# epoch = 264, loss = 2.1948
# epoch = 265, loss = 2.19137
# epoch = 266, loss = 2.18795
# epoch = 267, loss = 2.18454
# epoch = 268, loss = 2.18114
# epoch = 269, loss = 2.17775
# epoch = 270, loss = 2.17437
# epoch = 271, loss = 2.17099
# epoch = 272, loss = 2.16763
# epoch = 273, loss = 2.16427
# epoch = 274, loss = 2.16093
# epoch = 275, loss = 2.15759
# epoch = 276, loss = 2.15426
# epoch = 277, loss = 2.15094
# epoch = 278, loss = 2.14763
# epoch = 279, loss = 2.14433
# epoch = 280, loss = 2.14104
# epoch = 281, loss = 2.13776
# epoch = 282, loss = 2.13448
# epoch = 283, loss = 2.13122
# epoch = 284, loss = 2.12796
# epoch = 285, loss = 2.12471
# epoch = 286, loss = 2.12147
# epoch = 287, loss = 2.11824
# epoch = 288, loss = 2.11501
# epoch = 289, loss = 2.1118
# epoch = 290, loss = 2.10859
# epoch = 291, loss = 2.10539
# epoch = 292, loss = 2.1022
# epoch = 293, loss = 2.09902
# epoch = 294, loss = 2.09584
# epoch = 295, loss = 2.09268
# epoch = 296, loss = 2.08952
# epoch = 297, loss = 2.08637
# epoch = 298, loss = 2.08323
# epoch = 299, loss = 2.08009
# epoch = 300, loss = 2.07697
# epoch = 301, loss = 2.07385
# epoch = 302, loss = 2.07074
# epoch = 303, loss = 2.06763
# epoch = 304, loss = 2.06454
# epoch = 305, loss = 2.06145
# epoch = 306, loss = 2.05837
# epoch = 307, loss = 2.0553
# epoch = 308, loss = 2.05224
# epoch = 309, loss = 2.04918
# epoch = 310, loss = 2.04613
# epoch = 311, loss = 2.04309
# epoch = 312, loss = 2.04006
# epoch = 313, loss = 2.03703
# epoch = 314, loss = 2.03401
# epoch = 315, loss = 2.031
# epoch = 316, loss = 2.028
# epoch = 317, loss = 2.025
# epoch = 318, loss = 2.02201
# epoch = 319, loss = 2.01903
# epoch = 320, loss = 2.01605
# epoch = 321, loss = 2.01309
# epoch = 322, loss = 2.01013
# epoch = 323, loss = 2.00717
# epoch = 324, loss = 2.00423
# epoch = 325, loss = 2.00129
# epoch = 326, loss = 1.99836
# epoch = 327, loss = 1.99543
# epoch = 328, loss = 1.99252
# epoch = 329, loss = 1.98961
# epoch = 330, loss = 1.9867
# epoch = 331, loss = 1.98381
# epoch = 332, loss = 1.98092
# epoch = 333, loss = 1.97804
# epoch = 334, loss = 1.97516
# epoch = 335, loss = 1.97229
# epoch = 336, loss = 1.96943
# epoch = 337, loss = 1.96658
# epoch = 338, loss = 1.96373
# epoch = 339, loss = 1.96089
# epoch = 340, loss = 1.95805
# epoch = 341, loss = 1.95522
# epoch = 342, loss = 1.9524
# epoch = 343, loss = 1.94959
# epoch = 344, loss = 1.94678
# epoch = 345, loss = 1.94398
# epoch = 346, loss = 1.94119
# epoch = 347, loss = 1.9384
# epoch = 348, loss = 1.93562
# epoch = 349, loss = 1.93284
# epoch = 350, loss = 1.93008
# epoch = 351, loss = 1.92732
# epoch = 352, loss = 1.92456
# epoch = 353, loss = 1.92181
# epoch = 354, loss = 1.91907
# epoch = 355, loss = 1.91634
# epoch = 356, loss = 1.91361
# epoch = 357, loss = 1.91088
# epoch = 358, loss = 1.90817
# epoch = 359, loss = 1.90546
# epoch = 360, loss = 1.90276
# epoch = 361, loss = 1.90006
# epoch = 362, loss = 1.89737
# epoch = 363, loss = 1.89468
# epoch = 364, loss = 1.89201
# epoch = 365, loss = 1.88933
# epoch = 366, loss = 1.88667
# epoch = 367, loss = 1.88401
# epoch = 368, loss = 1.88136
# epoch = 369, loss = 1.87871
# epoch = 370, loss = 1.87607
# epoch = 371, loss = 1.87343
# epoch = 372, loss = 1.8708
# epoch = 373, loss = 1.86818
# epoch = 374, loss = 1.86557
# epoch = 375, loss = 1.86296
# epoch = 376, loss = 1.86035
# epoch = 377, loss = 1.85775
# epoch = 378, loss = 1.85516
# epoch = 379, loss = 1.85257
# epoch = 380, loss = 1.84999
# epoch = 381, loss = 1.84742
# epoch = 382, loss = 1.84485
# epoch = 383, loss = 1.84229
# epoch = 384, loss = 1.83973
# epoch = 385, loss = 1.83718
# epoch = 386, loss = 1.83464
# epoch = 387, loss = 1.8321
# epoch = 388, loss = 1.82957
# epoch = 389, loss = 1.82704
# epoch = 390, loss = 1.82452
# epoch = 391, loss = 1.822
# epoch = 392, loss = 1.81949
# epoch = 393, loss = 1.81699
# epoch = 394, loss = 1.81449
# epoch = 395, loss = 1.812
# epoch = 396, loss = 1.80951
# epoch = 397, loss = 1.80703
# epoch = 398, loss = 1.80455
# epoch = 399, loss = 1.80208
# epoch = 400, loss = 1.79962
# epoch = 401, loss = 1.79716
# epoch = 402, loss = 1.79471
# epoch = 403, loss = 1.79226
# epoch = 404, loss = 1.78982
# epoch = 405, loss = 1.78738
# epoch = 406, loss = 1.78495
# epoch = 407, loss = 1.78253
# epoch = 408, loss = 1.78011
# epoch = 409, loss = 1.7777
# epoch = 410, loss = 1.77529
# epoch = 411, loss = 1.77289
# epoch = 412, loss = 1.77049
# epoch = 413, loss = 1.7681
# epoch = 414, loss = 1.76571
# epoch = 415, loss = 1.76333
# epoch = 416, loss = 1.76095
# epoch = 417, loss = 1.75858
# epoch = 418, loss = 1.75622
# epoch = 419, loss = 1.75386
# epoch = 420, loss = 1.7515
# epoch = 421, loss = 1.74916
# epoch = 422, loss = 1.74681
# epoch = 423, loss = 1.74447
# epoch = 424, loss = 1.74214
# epoch = 425, loss = 1.73981
# epoch = 426, loss = 1.73749
# epoch = 427, loss = 1.73517
# epoch = 428, loss = 1.73286
# epoch = 429, loss = 1.73056
# epoch = 430, loss = 1.72825
# epoch = 431, loss = 1.72596
# epoch = 432, loss = 1.72367
# epoch = 433, loss = 1.72138
# epoch = 434, loss = 1.7191
# epoch = 435, loss = 1.71683
# epoch = 436, loss = 1.71456
# epoch = 437, loss = 1.71229
# epoch = 438, loss = 1.71003
# epoch = 439, loss = 1.70777
# epoch = 440, loss = 1.70553
# epoch = 441, loss = 1.70328
# epoch = 442, loss = 1.70104
# epoch = 443, loss = 1.69881
# epoch = 444, loss = 1.69658
# epoch = 445, loss = 1.69435
# epoch = 446, loss = 1.69213
# epoch = 447, loss = 1.68992
# epoch = 448, loss = 1.68771
# epoch = 449, loss = 1.6855
# epoch = 450, loss = 1.6833
# epoch = 451, loss = 1.68111
# epoch = 452, loss = 1.67892
# epoch = 453, loss = 1.67673
# epoch = 728, loss = 1.22524
# epoch = 729, loss = 1.22403
# epoch = 730, loss = 1.22282
# epoch = 731, loss = 1.22162
# epoch = 732, loss = 1.22042
# epoch = 733, loss = 1.21922
# epoch = 734, loss = 1.21802
# epoch = 735, loss = 1.21682
# epoch = 736, loss = 1.21563
# epoch = 737, loss = 1.21444
# epoch = 738, loss = 1.21325
# epoch = 739, loss = 1.21207
# epoch = 740, loss = 1.21088
# epoch = 741, loss = 1.2097
# epoch = 742, loss = 1.20852
# epoch = 743, loss = 1.20735
# epoch = 744, loss = 1.20617
# epoch = 745, loss = 1.205
# epoch = 746, loss = 1.20383
# epoch = 747, loss = 1.20267
# epoch = 748, loss = 1.2015
# epoch = 749, loss = 1.20034
# epoch = 750, loss = 1.19918
# epoch = 751, loss = 1.19803
# epoch = 752, loss = 1.19687
# epoch = 753, loss = 1.19572
# epoch = 754, loss = 1.19457
# epoch = 755, loss = 1.19342
# epoch = 756, loss = 1.19227
# epoch = 757, loss = 1.19113
# epoch = 758, loss = 1.18999
# epoch = 759, loss = 1.18885
# epoch = 760, loss = 1.18772
# epoch = 761, loss = 1.18658
# epoch = 762, loss = 1.18545
# epoch = 763, loss = 1.18432
# epoch = 764, loss = 1.18319
# epoch = 765, loss = 1.18207
# epoch = 766, loss = 1.18094
# epoch = 767, loss = 1.17982
# epoch = 768, loss = 1.17871
# epoch = 769, loss = 1.17759
# epoch = 770, loss = 1.17648
# epoch = 771, loss = 1.17536
# epoch = 772, loss = 1.17425
# epoch = 773, loss = 1.17315
# epoch = 774, loss = 1.17204
# epoch = 775, loss = 1.17094
# epoch = 776, loss = 1.16984
# epoch = 777, loss = 1.16874
# epoch = 778, loss = 1.16765
# epoch = 779, loss = 1.16655
# epoch = 780, loss = 1.16546
# epoch = 781, loss = 1.16437
# epoch = 782, loss = 1.16328
# epoch = 783, loss = 1.1622
# epoch = 784, loss = 1.16111
# epoch = 785, loss = 1.16003
# epoch = 786, loss = 1.15895
# epoch = 787, loss = 1.15788
# epoch = 788, loss = 1.1568
# epoch = 789, loss = 1.15573
# epoch = 790, loss = 1.15466
# epoch = 791, loss = 1.15359
# epoch = 792, loss = 1.15253
# epoch = 793, loss = 1.15146
# epoch = 794, loss = 1.1504
# epoch = 795, loss = 1.14934
# epoch = 796, loss = 1.14828
# epoch = 797, loss = 1.14723
# epoch = 798, loss = 1.14617
# epoch = 799, loss = 1.14512
# epoch = 800, loss = 1.14407
# epoch = 801, loss = 1.14303
# epoch = 802, loss = 1.14198
# epoch = 803, loss = 1.14094
# epoch = 804, loss = 1.1399
# epoch = 805, loss = 1.13886
# epoch = 806, loss = 1.13782
# epoch = 807, loss = 1.13678
# epoch = 808, loss = 1.13575
# epoch = 809, loss = 1.13472
# epoch = 810, loss = 1.13369
# epoch = 811, loss = 1.13267
# epoch = 812, loss = 1.13164
# epoch = 813, loss = 1.13062
# epoch = 814, loss = 1.1296
# epoch = 815, loss = 1.12858
# epoch = 816, loss = 1.12756
# epoch = 817, loss = 1.12655
# epoch = 818, loss = 1.12553
# epoch = 1948, loss = 0.610478
# epoch = 1949, loss = 0.610279
# epoch = 1950, loss = 0.61008
# epoch = 1951, loss = 0.609881
# epoch = 1952, loss = 0.609683
# epoch = 1953, loss = 0.609484
# epoch = 1954, loss = 0.609286
# epoch = 1955, loss = 0.609088
# epoch = 1956, loss = 0.60889
# epoch = 1957, loss = 0.608693
# epoch = 1958, loss = 0.608495
# epoch = 1959, loss = 0.608298
# epoch = 1960, loss = 0.608101
# epoch = 1961, loss = 0.607904
# epoch = 1962, loss = 0.607708
# epoch = 1963, loss = 0.607511
# epoch = 1964, loss = 0.607315
# epoch = 1965, loss = 0.607119
# epoch = 1966, loss = 0.606923
# epoch = 1967, loss = 0.606727
# epoch = 1968, loss = 0.606532
# epoch = 1969, loss = 0.606336
# epoch = 1970, loss = 0.606141
# epoch = 1971, loss = 0.605946
# epoch = 1972, loss = 0.605752
# epoch = 1973, loss = 0.605557
# epoch = 1974, loss = 0.605363
# epoch = 1975, loss = 0.605168
# epoch = 1976, loss = 0.604974
# epoch = 1977, loss = 0.60478
# epoch = 1978, loss = 0.604587
# epoch = 1979, loss = 0.604393
# epoch = 1980, loss = 0.6042
# epoch = 1981, loss = 0.604007
# epoch = 1982, loss = 0.603814
# epoch = 1983, loss = 0.603621
# epoch = 1984, loss = 0.603428
# epoch = 1985, loss = 0.603236
# epoch = 1986, loss = 0.603044
# epoch = 1987, loss = 0.602852
# epoch = 1988, loss = 0.60266
# epoch = 1989, loss = 0.602468
# epoch = 1990, loss = 0.602277
# epoch = 1991, loss = 0.602085
# epoch = 1992, loss = 0.601894
# epoch = 1993, loss = 0.601703
# epoch = 1994, loss = 0.601512
# epoch = 1995, loss = 0.601322
# epoch = 1996, loss = 0.601131
# epoch = 1997, loss = 0.600941
# epoch = 1998, loss = 0.600751
# epoch = 1999, loss = 0.600561

# %% [markdown]
# Plotting loss to visualize model convergence

# %%
import matplotlib.pyplot as plt

# plot the loss
plt.plot(range(len(loss_history)),loss_history)
plt.axis([0,training_epochs,0,np.max(loss_history)])
plt.show()

print("Model loss : " + str(loss_history[-1]))
# Out:
# Model loss : 0.6003710031509399

# %% [markdown]
# Once we have trained the model, we can test it on the test set

# %%
# Prepare test data
x_test = np.matrix(test_df.loc[:, features]).transpose()

# Load entire label intro matrix
y_test = np.matrix(test_df['log_price'])

# Make some predictions on test dataset and calculate mean square error
prediction_y_test = session.run(y_predicted, feed_dict={x: x_test})
mse = tf.reduce_mean(tf.square(prediction_y_test - y_test))
print("Test RMSE: %.4f" % session.run(mse)) 

y_test = np.ravel(y_test.sum(axis=0))
prediction_y_test = prediction_y_test[0]

fig, ax = plt.subplots()
ax.scatter(y_test, prediction_y_test)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=3)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()
# Out:
# MSE: 0.5972
# [6.05208917 4.90527478 5.52146092 ... 5.22035583 5.6167711  5.48063892]
# [5.21283   5.4127436 6.4659085 ... 5.5269427 5.4717417 5.225314 ]

# %% [markdown]
# The test mean square error is quite close to the model RMSE. Therefore, the model performs well at the test set.
